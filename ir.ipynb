# %% [markdown]
# Use bash

# %%
# %%bash
# echo "Prima riga"
# echo "Seconda riga"
# Out:
# Prima riga
# Seconda riga

# %% [markdown]
# Esempio di lynx che salva il risultato in un file txt

# %%
# %%bash
# lynx -dump https://www.wikipedia.org >> results/wikipedia.txt

# %%
# %%bash
# lynx -dump -listonly https://www.wikipedia.org
# Out:
# References
#
#    Visible links:
#    1. https://en.wikipedia.org/
#    2. https://ja.wikipedia.org/
#    3. https://ru.wikipedia.org/
#    4. https://de.wikipedia.org/
#    5. https://fr.wikipedia.org/
#    6. https://es.wikipedia.org/
#    7. https://zh.wikipedia.org/
#    8. https://it.wikipedia.org/
#    9. https://pl.wikipedia.org/
#   10. https://pt.wikipedia.org/
#   11. https://ar.wikipedia.org/
#   12. https://de.wikipedia.org/
#   13. https://en.wikipedia.org/
#   14. https://es.wikipedia.org/
#   15. https://fa.wikipedia.org/
#   16. https://fr.wikipedia.org/
#   17. https://it.wikipedia.org/
#   18. https://arz.wikipedia.org/
#   19. https://nl.wikipedia.org/
#   20. https://ja.wikipedia.org/
#   21. https://pl.wikipedia.org/
#   22. https://pt.wikipedia.org/
#   23. https://ceb.wikipedia.org/
#   24. https://sv.wikipedia.org/
#   25. https://uk.wikipedia.org/
#   26. https://vi.wikipedia.org/
#   27. https://war.wikipedia.org/
#   28. https://zh.wikipedia.org/
# ...

# %%
import sys
import subprocess

subprocess.run([
    sys.executable, "crowler.py",
    "-u", "http://www.amiciinsoliti.altervista.org/index.shtml",
    "-d", "1",
])
# Out:
# --------------------------------------------------------------------------------
# Recursive Web Crawler starting at 26/09/2025 15:25:36
# --------------------------------------------------------------------------------
# [*] URL              : http://www.amiciinsoliti.altervista.org/index.shtml
# [*] Max Depth        : 2
# --------------------------------------------------------------------------------
# [+] Subdomains : https://www.mase.gov.it/portale/accordo-di-programma-panni-tecnici
# [+] Subdomains : https://www.mase.gov.it/portale/organizzazione
# [+] Subdomains : https://www.mase.gov.it/portale/educazione-ambientale
# [+] Subdomains : https://www.mase.gov.it/portale/ufficio-stampa
# [+] Subdomains : https://www.mase.gov.it/portale/enti-controllati
# [+] Subdomains : https://www.iubenda.com/it/
# [+] Subdomains : http://www.minambiente.it/home_it/menu.html?mp=/menu/menu_attivita/&m=Rete_Natura_2000.html%7CRN2000_Direttiva_Habitat.html
# ...
